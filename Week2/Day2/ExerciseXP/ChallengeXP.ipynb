# %% [markdown]
# <a href="https://colab.research.google.com/github/y-fares/PSTB_DI_Bootcamp/blob/main/Week2/Day2/ExerciseXP/ChallengeXP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1: Identifying Data Types
# Below are various data sources. Identify whether each one is an example of structured or unstructured data.
#
# 1 - A company’s financial reports stored in an Excel file.
#
# 2 - Photographs uploaded to a social media platform.
#
# 3 - A collection of news articles on a website.
#
# 4 - Inventory data in a relational database.
# Recorded interviews from a market research study.

# %% [markdown]
# | Data Types                                             |  structured or unstructured data                                                            |
# | -------------------------------------------------------|---------------------------------------------------------------------------------------------|
# | A company’s financial reports stored in an Excel file  |  Structured data (Organized in rows and columns, easily searchable and analyzable.)         |
# | Photographs uploaded to a social media platform        |  Unstructured data (Images have no predefined format or schema.)                            |
# | A collection of news articles on a website             |  Unstructured data (Text content varies widely; not stored in a consistent, tabular format.)|
# | Inventory data in a relational database                |  Structured data (Highly organized into tables with defined fields and data types.)         |
# | Recorded interviews from a market research study       |  Unstructured data (Audio files without inherent structure; content must be interpreted.)

# %% [markdown]
# Exercise 2: Transformation Exercise
# For each of the following unstructured data sources, propose a method to convert it into structured data. Explain your reasoning.
#
# 1 - A series of blog posts about travel experiences.
#
# 2 - Audio recordings of customer service calls.
#
# 3 - Handwritten notes from a brainstorming session.
#
# 4 - A video tutorial on cooking.

# %% [markdown]
# | unstructured data sources                         | method to convert it into structured data                                   |
# |---------------------------------------------------|-----------------------------------------------------------------------------|
# | A series of blog posts about travel experiences.  |Use Natural Language Processing (NLP) and text mining                        |
# | Audio recordings of customer service calls.       |Apply Speech-to-Text transcription followed by sentiment and topic analysis  |
# | Handwritten notes from a brainstorming session.   |Use Optical Character Recognition (OCR) and text classification              |
# | A video tutorial on cooking.                      |Combine video analysis, image recognition, and Speech-to-Text transcription  |

# %% [markdown]
# Exercise 3 : Import a file from Kaggle
# Note: This dataset was originally sourced from Kaggle, but for easier access, it has been made available on GitHub.
#
# 👉 Please download the dataset directly from the GitHub repository to use it in this project.
#
# Import the train dataset. Use the train.csv file.
# Print the first few rows of the DataFrame.

# %%
# !wget https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/train.zip
# Out:
# --2025-10-10 10:20:08--  https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/train.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/devtlv/Datasets-DA-Bootcamp-2-/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data%2C%20Exporting%20D/train.zip [following]
# --2025-10-10 10:20:08--  https://media.githubusercontent.com/media/devtlv/Datasets-DA-Bootcamp-2-/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data%2C%20Exporting%20D/train.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#   inflating: train.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Exercise 4: Importing a CSV File
# Use the Iris Dataset CSV.
#
# Download the Iris dataset CSV file and place it in the same directory as your Jupyter Notebook.
# Import the CSV file using Pandas.
# Display the first five rows of the dataset.

# %%
# !wget https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/Iris_dataset.zip
# Out:
# --2025-10-10 10:21:50--  https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/Iris_dataset.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/devtlv/Datasets-DA-Bootcamp-2-/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data%2C%20Exporting%20D/Iris_dataset.zip [following]
# --2025-10-10 10:21:51--  https://media.githubusercontent.com/media/devtlv/Datasets-DA-Bootcamp-2-/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data%2C%20Exporting%20D/Iris_dataset.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# ...

# %%
# !unzip Iris_dataset.zip
# Out:
# Archive:  Iris_dataset.zip
#   inflating: Iris_dataset.csv

# %%
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df_iris = pd.read_csv("Iris_dataset.csv", names=col_names, header=None)
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Exercise 5 : Export a dataframe to excel format and JSON format.
# Create a simple dataframe.
# Export the dataframe to an excel file.
# Export the dataframe to a JSON file.

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Paris', 'Lyon', 'Marseille']
}
df = pd.DataFrame(data)

# %% [markdown]
#  Export the dataframe to an excel file

# %%
df.to_excel('people.xlsx', index=False)

# %% [markdown]
# Export the dataframe to a JSON file.

# %%
df.to_json('people.json', orient='records', indent=4)

# %% [markdown]
# Exercise 6: Reading JSON Data
# Use a sample JSON dataset
#
# Import the JSON data from the provided URL.
# Use Pandas to read the JSON data.
# Display the first five entries of the data.

# %%
# !wget https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/posts.zip
# Out:
# --2025-10-10 10:28:51--  https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/posts.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/devtlv/Datasets-DA-Bootcamp-2-/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data%2C%20Exporting%20D/posts.zip [following]
# --2025-10-10 10:28:51--  https://media.githubusercontent.com/media/devtlv/Datasets-DA-Bootcamp-2-/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data%2C%20Exporting%20D/posts.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# !unzip posts.zip
# Out:
# Archive:  posts.zip
#   inflating: posts.json

# %% [markdown]
# Use Pandas to read the JSON data.

# %%
df_json = pd.read_json("posts.json")

# %% [markdown]
# Display the first five entries of the data.

# %%
df_json.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
